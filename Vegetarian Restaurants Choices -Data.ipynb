# %% [markdown]
# ## Data Used
#
# The data we used here consists of 3 parts:
#
# 1. Neighbourhood Data in Manhattan City
#     * This data consists of Borough, Neighborhood, Latitude, Longitude of each neighbourhood in Manhattan.
#     * This gives us a base on the search and definition of our location scope.
#
# 1. Foursquare API Data
#     * This is information we obtained from Foursquare basing in the "search" funtion.
#     * We will obtain Neighborhood,	Neighborhood Latitude,	Neighborhood Longitude,	Venue,	Venue Latitude,	Venue Longitude and venue category indicated in Foursquare.
#     * In this study, we will only focus on gym and restaurants.
#
# 1. Google API Data
#     * Basing in the list in point 1, we also obtain user rating and overall ratings from Google API.
#     * In this study, we only focus in the scope for gym and restaurants.

# %%
#Neighbourhood Data in Manhattan City Example

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe


# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
    
neighborhoods_data = newyork_data['features'] 
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

neighborhoods.head()
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.49         |             py_0          32 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     geopy-1.19.0               |             py_0          53 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.49-py_0         conda-forge
#     geopy:           1.19.0-py_0       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#     openssl:         1.0.2p-h14c3975_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# geographiclib-1.49   | 32 KB     | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# geopy-1.19.0         | 53 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
#Neighbourhood Data in Manhattan City Example

for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
#Foursquare API Example


CLIENT_ID = 'E0U0BEG0FBKSIC3ENYPY1ZSTXQY0KPX31Z4GBYKOWJTIPLNH' # your Foursquare ID
CLIENT_SECRET = '0FAIRZHCUOG1GXLBSZOFL2NXXE1FKONACI4PN03GXMWP4QMA' # your Foursquare Secret
VERSION = '20190511' # Foursquare API version
lat=40.89
lng=-73.91

radius=500
LIMIT=100

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
results = requests.get(url).json()["response"]['groups'][0]['items']
results
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4c268383136d20a15a83e561-0',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d164941735',
#      'name': 'Plaza',
#      'pluralName': 'Plazas',
#      'primary': True,
#      'shortName': 'Plaza'}],
#    'id': '4c268383136d20a15a83e561',
#    'location': {'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 51,
#     'formattedAddress': ['Bronx, NY 10463', 'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.890424929507866,
#       'lng': -73.91024841803598}],
#     'lat': 40.890424929507866,
#     'lng': -73.91024841803598,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Riverdale Ave',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4f2c66f7e4b0ccfb1df00308-1',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d16c941735',
#      'name': 'Burger Joint',
#      'pluralName': 'Burger Joints',
#      'primary': True,
#      'shortName': 'Burgers'}],
#    'id': '4f2c66f7e4b0ccfb1df00308',
#    'location': {'address': '3726 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 379,
#     'formattedAddress': ['3726 Riverdale Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88733734314313,
#       'lng': -73.9071843648891}],
#     'lat': 40.88733734314313,
#     'lng': -73.9071843648891,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Yo-Burger',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-51cc87aa498e0e8caff2fe59-2',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1d0941735',
#      'name': 'Dessert Shop',
#      'pluralName': 'Dessert Shops',
#      'primary': True,
#      'shortName': 'Desserts'}],
#    'id': '51cc87aa498e0e8caff2fe59',
#    'location': {'address': '3555 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'at W 236th St',
#     'distance': 378,
#     'formattedAddress': ['3555 Johnson Ave (at W 236th St)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display', 'lat': 40.8866, 'lng': -73.90991}],
#     'lat': 40.8866,
#     'lng': -73.90991,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Menchie's",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4f653ac0e4b0bf1012abaf2d-3',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tapas_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1db931735',
#      'name': 'Tapas Restaurant',
#      'pluralName': 'Tapas Restaurants',
#      'primary': True,
#      'shortName': 'Tapas'}],
#    'id': '4f653ac0e4b0bf1012abaf2d',
#    'location': {'address': '3708 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': '236th',
#     'distance': 404,
#     'formattedAddress': ['3708 Riverdale Ave (236th)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88707311362176,
#       'lng': -73.90714828242368}],
#     'lat': 40.88707311362176,
#     'lng': -73.90714828242368,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Tin Marin',
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '50119340'}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-503cfaffe4b066d39de5005a-4',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'primary': True,
#      'shortName': 'Japanese'}],
#    'id': '503cfaffe4b066d39de5005a',
#    'location': {'address': '3532A Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 417,
#     'formattedAddress': ['3532A Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88625663623957,
#       'lng': -73.90971942607067}],
#     'lat': 40.88625663623957,
#     'lng': -73.90971942607067,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Aoyu Japanese Restaurant',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4bc39d1d2a89ef3bdf49f588-5',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10e941735',
#      'name': 'Greek Restaurant',
#      'pluralName': 'Greek Restaurants',
#      'primary': True,
#      'shortName': 'Greek'}],
#    'id': '4bc39d1d2a89ef3bdf49f588',
#    'location': {'address': '3733 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'W 238th St',
#     'distance': 361,
#     'formattedAddress': ['3733 Riverdale Ave (W 238th St)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88749950271757,
#       'lng': -73.90726184172892}],
#     'lat': 40.88749950271757,
#     'lng': -73.90726184172892,
#     'neighborhood': 'Riverdale',
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Greek Express',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4c6994e3c946e21eb28eea8e-6',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'primary': True,
#      'shortName': 'Pizza'}],
#    'id': '4c6994e3c946e21eb28eea8e',
#    'location': {'address': '3738 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'at 238th Street.',
#     'distance': 354,
#     'formattedAddress': ['3738 Riverdale Ave (at 238th Street.)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.887632762259415,
#       'lng': -73.90717756259086}],
#     'lat': 40.887632762259415,
#     'lng': -73.90717756259086,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Salvatore's of Soho",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-59dbf19108f521354f91e748-7',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'primary': True,
#      'shortName': 'Restaurant'}],
#    'id': '59dbf19108f521354f91e748',
#    'location': {'address': '3541 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': '236th',
#     'distance': 462,
#     'formattedAddress': ['3541 Riverdale Ave (236th)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.886459,
#       'lng': -73.90712}],
#     'lat': 40.886459,
#     'lng': -73.90712,
#     'neighborhood': 'Central Riverdale',
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'The Hill Bistro',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b0b311af964a520642e23e3-8',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'primary': True,
#      'shortName': 'Japanese'}],
#    'delivery': {'id': '332329',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/palace-of-japan-3505-johnson-ave-bronx/332329?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=332329'},
#    'id': '4b0b311af964a520642e23e3',
#    'location': {'address': '3505 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'btwn 235th and 236th',
#     'distance': 463,
#     'formattedAddress': ['3505 Johnson Ave (btwn 235th and 236th)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88584088190632,
#       'lng': -73.91006439099525}],
#     'lat': 40.88584088190632,
#     'lng': -73.91006439099525,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Palace of Japan',
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '81196358'}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-590e5d2ce96d0c61de2dcf1d-9',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'primary': True,
#      'shortName': 'Mexican'}],
#    'delivery': {'id': '538168',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/cocina-chente-3535-riverdale-ave-bronx/538168?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=538168'},
#    'id': '590e5d2ce96d0c61de2dcf1d',
#    'location': {'address': '3535 Riverdale Ave',
#     'cc': 'US',
#     'city': 'New York',
#     'country': 'United States',
#     'distance': 484,
#     'formattedAddress': ['3535 Riverdale Ave',
#      'New York, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88623511155728,
#       'lng': -73.90710752064396}],
#     'lat': 40.88623511155728,
#     'lng': -73.90710752064396,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Cocina Chente',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b7993cbf964a520c8022fe3-10',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'primary': True,
#      'shortName': 'Deli / Bodega'}],
#    'delivery': {'id': '275609',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/liebmans-deli-552-w-235th-st-bronx/275609?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=275609'},
#    'id': '4b7993cbf964a520c8022fe3',
#    'location': {'address': '552 W 235th St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Johnson Ave',
#     'distance': 492,
#     'formattedAddress': ['552 W 235th St (Johnson Ave)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88558431627006,
#       'lng': -73.90967819364165}],
#     'lat': 40.88558431627006,
#     'lng': -73.90967819364165,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Liebman's Kosher Deli",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4bf9ecdd5efe2d7fb20b6d34-11',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10a951735',
#      'name': 'Bank',
#      'pluralName': 'Banks',
#      'primary': True,
#      'shortName': 'Bank'}],
#    'id': '4bf9ecdd5efe2d7fb20b6d34',
#    'location': {'address': '3775 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 275,
#     'formattedAddress': ['3775 Riverdale Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.888089,
#       'lng': -73.907921}],
#     'lat': 40.888089,
#     'lng': -73.907921,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Chase Bank',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4bf865a24a67c928215e25cf-12',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'primary': True,
#      'shortName': 'Pizza'}],
#    'delivery': {'id': '72553',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/pizza-chef-564-w-235th-st-riverdale/72553?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=72553'},
#    'id': '4bf865a24a67c928215e25cf',
#    'location': {'address': '564 W 235th St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'btw Johnson & Netherland',
#     'distance': 485,
#     'formattedAddress': ['564 W 235th St (btw Johnson & Netherland)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88563972079103,
#       'lng': -73.91024487885741}],
#     'lat': 40.88563972079103,
#     'lng': -73.91024487885741,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Pizza Chef',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-55bfeb40498e061fef3632ca-13',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'},
#      'id': '54541900498ea6ccd0202697',
#      'name': 'Health & Beauty Service',
#      'pluralName': 'Health & Beauty Services',
#      'primary': True,
#      'shortName': 'Health & Beauty'}],
#    'id': '55bfeb40498e061fef3632ca',
#    'location': {'address': '3548 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'West 236th Street',
#     'distance': 397,
#     'formattedAddress': ['3548 Johnson Ave (West 236th Street)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88643352606939,
#       'lng': -73.90976040650955}],
#     'lat': 40.88643352606939,
#     'lng': -73.90976040650955,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'European Wax Center',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-52f66c1b498ecf329becd4a5-14',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'primary': True,
#      'shortName': 'Donuts'}],
#    'id': '52f66c1b498ecf329becd4a5',
#    'location': {'address': '568 W 235th St #570',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 488,
#     'formattedAddress': ['568 W 235th St #570',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.885620986101195,
#       'lng': -73.91037467055224}],
#     'lat': 40.885620986101195,
#     'lng': -73.91037467055224,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Dunkin'",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-53683f34498e6d121eeecbdf-15',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'primary': True,
#      'shortName': 'Bar'}],
#    'id': '53683f34498e6d121eeecbdf',
#    'location': {'address': '3713 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 383,
#     'formattedAddress': ['3713 Riverdale Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.887253200116284,
#       'lng': -73.9072508524159}],
#     'lat': 40.887253200116284,
#     'lng': -73.9072508524159,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Blackstone Bar & Grill',
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '370316852'}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-49d73e8ff964a5201f5d1fe3-16',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'primary': True,
#      'shortName': 'Coffee Shop'}],
#    'id': '49d73e8ff964a5201f5d1fe3',
#    'location': {'address': '3503 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'at W 235th St',
#     'distance': 467,
#     'formattedAddress': ['3503 Johnson Ave (at W 235th St)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88580402,
#       'lng': -73.91015796}],
#     'lat': 40.88580402,
#     'lng': -73.91015796,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Starbucks',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b0aa321f964a520db2523e3-17',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d179941735',
#      'name': 'Bagel Shop',
#      'pluralName': 'Bagel Shops',
#      'primary': True,
#      'shortName': 'Bagels'}],
#    'id': '4b0aa321f964a520db2523e3',
#    'location': {'address': '3601 Riverdale Ave',
#     'cc': 'US',
#     'city': 'New York',
#     'country': 'United States',
#     'crossStreet': '236th St.',
#     'distance': 445,
#     'formattedAddress': ['3601 Riverdale Ave (236th St.)',
#      'New York, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88662386774234,
#       'lng': -73.90716818359404}],
#     'lat': 40.88662386774234,
#     'lng': -73.90716818359404,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Rolen Bagels',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-505223ade4b0252d0552ef9a-18',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d147941735',
#      'name': 'Diner',
#      'pluralName': 'Diners',
#      'primary': True,
#      'shortName': 'Diner'}],
#    'delivery': {'id': '274985',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/tinys-diner-3603-riverdale-ave-bronx/274985?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=274985'},
#    'id': '505223ade4b0252d0552ef9a',
#    'location': {'address': '3603 Riverdale Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 439,
#     'formattedAddress': ['3603 Riverdale Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8866525233077,
#       'lng': -73.90722113692334}],
#     'lat': 40.8866525233077,
#     'lng': -73.90722113692334,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Tiny's Diner",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4bd1ecfab221c9b61a85d6d0-19',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d119951735',
#      'name': 'Wine Shop',
#      'pluralName': 'Wine Shops',
#      'primary': True,
#      'shortName': 'Wine Shop'}],
#    'id': '4bd1ecfab221c9b61a85d6d0',
#    'location': {'address': '549 W 235th St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Johnson avenue',
#     'distance': 478,
#     'formattedAddress': ['549 W 235th St (Johnson avenue)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.885700777316806,
#       'lng': -73.90991985104387}],
#     'lat': 40.885700777316806,
#     'lng': -73.90991985104387,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Riverdale Vintner',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b94a4a2f964a520787f34e3-20',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d149941735',
#      'name': 'Thai Restaurant',
#      'pluralName': 'Thai Restaurants',
#      'primary': True,
#      'shortName': 'Thai'}],
#    'id': '4b94a4a2f964a520787f34e3',
#    'location': {'address': '3525 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 421,
#     'formattedAddress': ['3525 Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88621093794359,
#       'lng': -73.90999084202346}],
#     'lat': 40.88621093794359,
#     'lng': -73.90999084202346,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Nam Thai',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4d8cab35fe8d41bd823bd705-21',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'primary': True,
#      'shortName': 'Pizza'}],
#    'id': '4d8cab35fe8d41bd823bd705',
#    'location': {'address': '161 W 231st St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 370,
#     'formattedAddress': ['161 W 231st St', 'Bronx, NY 10463', 'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88688268179659,
#       'lng': -73.9084571226761}],
#     'lat': 40.88688268179659,
#     'lng': -73.9084571226761,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': "Papa John's Pizza",
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4befee5dd4e4d13addab15a7-22',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d179941735',
#      'name': 'Bagel Shop',
#      'pluralName': 'Bagel Shops',
#      'primary': True,
#      'shortName': 'Bagels'}],
#    'id': '4befee5dd4e4d13addab15a7',
#    'location': {'address': '581 W 235th St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Netherland Ave',
#     'distance': 464,
#     'formattedAddress': ['581 W 235th St (Netherland Ave)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8858950171665,
#       'lng': -73.91095899709215}],
#     'lat': 40.8858950171665,
#     'lng': -73.91095899709215,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Bagel Corner',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-55aaee4d498e3cbb70e625d6-23',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'primary': True,
#      'shortName': 'Italian'}],
#    'delivery': {'id': '313525',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/bella-notte-pizzeria-3552-johnson-ave-bronx/313525?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=313525'},
#    'id': '55aaee4d498e3cbb70e625d6',
#    'location': {'address': '3552 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'West 236th Street',
#     'distance': 380,
#     'formattedAddress': ['3552 Johnson Ave (West 236th Street)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88659539353357,
#       'lng': -73.90955624657254}],
#     'lat': 40.88659539353357,
#     'lng': -73.90955624657254,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Bella Notte Pizzeria',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4db45c96fa8c350240e35919-24',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'primary': True,
#      'shortName': 'Mexican'}],
#    'delivery': {'id': '245981',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/metate-3515-johnson-ave-bronx/245981?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=245981'},
#    'id': '4db45c96fa8c350240e35919',
#    'location': {'address': '3515 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 438,
#     'formattedAddress': ['3515 Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88606100812527,
#       'lng': -73.91002951657676}],
#     'lat': 40.88606100812527,
#     'lng': -73.91002951657676,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Metate',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-575ef975498e47359524dffa-25',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#       'suffix': '.png'},
#      'id': '4f04afc02fb6e1c99f3db0bc',
#      'name': 'Mobile Phone Shop',
#      'pluralName': 'Mobile Phone Shops',
#      'primary': True,
#      'shortName': 'Mobile Phones'}],
#    'id': '575ef975498e47359524dffa',
#    'location': {'address': '3553 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 385,
#     'formattedAddress': ['3553 Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88653737016214,
#       'lng': -73.90996166709772}],
#     'lat': 40.88653737016214,
#     'lng': -73.90996166709772,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'AT&T Store',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4bf5bde194b2a593503bacee-26',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10f951735',
#      'name': 'Pharmacy',
#      'pluralName': 'Pharmacies',
#      'primary': True,
#      'shortName': 'Pharmacy'}],
#    'id': '4bf5bde194b2a593503bacee',
#    'location': {'address': '541 W 235th St',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Oxford Avenue',
#     'distance': 494,
#     'formattedAddress': ['541 W 235th St (Oxford Avenue)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8856035,
#       'lng': -73.9091599}],
#     'lat': 40.8856035,
#     'lng': -73.9091599,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Rite Aid',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b228437f964a520274824e3-27',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d147941735',
#      'name': 'Diner',
#      'pluralName': 'Diners',
#      'primary': True,
#      'shortName': 'Diner'}],
#    'delivery': {'id': '84668',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/blue-bay-restaurant-3533-johnson-ave-bronx/84668?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=84668'},
#    'id': '4b228437f964a520274824e3',
#    'location': {'address': '3533 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'btwn 235th and 236th',
#     'distance': 405,
#     'formattedAddress': ['3533 Johnson Ave (btwn 235th and 236th)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.886357747561455,
#       'lng': -73.90989609158233}],
#     'lat': 40.886357747561455,
#     'lng': -73.90989609158233,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Blue Bay Restaurant',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4b2286f1f964a5205a4824e3-28',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d145941735',
#      'name': 'Chinese Restaurant',
#      'pluralName': 'Chinese Restaurants',
#      'primary': True,
#      'shortName': 'Chinese'}],
#    'delivery': {'id': '996049',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/hunan-balcony-3511-johnson-ave-bronx/996049?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=996049'},
#    'id': '4b2286f1f964a5205a4824e3',
#    'location': {'address': '3511 Johnson Avenue',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'btwn 235th and 236th',
#     'distance': 440,
#     'formattedAddress': ['3511 Johnson Avenue (btwn 235th and 236th)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88603921117957,
#       'lng': -73.91003040604107}],
#     'lat': 40.88603921117957,
#     'lng': -73.91003040604107,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Hunan Balcony',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4de4f007d4c0704405a670ac-29',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10a951735',
#      'name': 'Bank',
#      'pluralName': 'Banks',
#      'primary': True,
#      'shortName': 'Bank'}],
#    'id': '4de4f007d4c0704405a670ac',
#    'location': {'address': '3517 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 430,
#     'formattedAddress': ['3517 Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.8861316,
#       'lng': -73.9100101}],
#     'lat': 40.8861316,
#     'lng': -73.9100101,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Capital One Bank',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4c04544df423a593ac83d116-30',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d10f941735',
#      'name': 'Indian Restaurant',
#      'pluralName': 'Indian Restaurants',
#      'primary': True,
#      'shortName': 'Indian'}],
#    'delivery': {'id': '22101',
#     'provider': {'icon': {'name': '/delivery_provider_seamless_20180129.png',
#       'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50]},
#      'name': 'seamless'},
#     'url': 'https://www.seamless.com/menu/cumin-indian-restaurant-3549-johnson-ave-bronx/22101?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=22101'},
#    'id': '4c04544df423a593ac83d116',
#    'location': {'address': '3549 Johnson Ave',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'distance': 394,
#     'formattedAddress': ['3549 Johnson Ave',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.886458613786466,
#       'lng': -73.90981597247142}],
#     'lat': 40.886458613786466,
#     'lng': -73.90981597247142,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Cumin Indian Cuisine',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4e763197814ddff25ef75d0b-31',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1fe931735',
#      'name': 'Bus Station',
#      'pluralName': 'Bus Stations',
#      'primary': True,
#      'shortName': 'Bus Station'}],
#    'id': '4e763197814ddff25ef75d0b',
#    'location': {'address': '246th Street',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Henry Hudson Pkway / NY 9A',
#     'distance': 424,
#     'formattedAddress': ['246th Street (Henry Hudson Pkway / NY 9A)',
#      'Bronx, NY',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.89354823043404,
#       'lng': -73.90815138816833}],
#     'lat': 40.89354823043404,
#     'lng': -73.90815138816833,
#     'state': 'NY'},
#    'name': 'MTA MaBSTOA Bus Bx7 / Bx10 / Bx20 / BxM1 / BxM2 / BxM18 at 246th St. / Hudson Parkway',
#    'photos': {'count': 0, 'groups': []}}},
#  {'reasons': {'count': 0,
#    'items': [{'reasonName': 'globalInteractionReason',
#      'summary': 'This spot is popular',
#      'type': 'general'}]},
#   'referralId': 'e-0-4dd313bc813091d61fba0036-32',
#   'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#       'suffix': '.png'},
#      'id': '4bf58dd8d48988d1cb941735',
#      'name': 'Food Truck',
#      'pluralName': 'Food Trucks',
#      'primary': True,
#      'shortName': 'Food Truck'}],
#    'id': '4dd313bc813091d61fba0036',
#    'location': {'address': '620 West 236th Street',
#     'cc': 'US',
#     'city': 'Bronx',
#     'country': 'United States',
#     'crossStreet': 'Independence Avenue',
#     'distance': 440,
#     'formattedAddress': ['620 West 236th Street (Independence Avenue)',
#      'Bronx, NY 10463',
#      'United States'],
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.888152518919604,
#       'lng': -73.9146232432107}],
#     'lat': 40.888152518919604,
#     'lng': -73.9146232432107,
#     'postalCode': '10463',
#     'state': 'NY'},
#    'name': 'Park Lunch',
#    'photos': {'count': 0, 'groups': []}}}]

# %%
#Google API Example

GOOGLE_API_KEY="AIzaSyBZiUxgwt1dEOACrvyCb90Nfmt1nYASuKM"
radius=500

type1='gym'
url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&key={}&type={}'.format(
            lat,
            lng, 
            radius, 
            GOOGLE_API_KEY,
                type1
        )

gym_results = requests.get(url).json()
gym_results
# Out:
# {'html_attributions': [],
#  'results': [{'geometry': {'location': {'lat': 40.8874741, 'lng': -73.9068869},
#     'viewport': {'northeast': {'lat': 40.8887917802915,
#       'lng': -73.90568881970849},
#      'southwest': {'lat': 40.88609381970851, 'lng': -73.9083867802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png',
#    'id': '8ca0eccb06e0aac7790f10a7186336c2ffc04752',
#    'name': 'Grounded Growth Yoga',
#    'place_id': 'ChIJ60nWcbzzwokRB654LshQ4Ig',
#    'plus_code': {'compound_code': 'V3PV+X6 The Bronx, New York, United States',
#     'global_code': '87G8V3PV+X6'},
#    'reference': 'ChIJ60nWcbzzwokRB654LshQ4Ig',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'vicinity': '3732 Riverdale Avenue, The Bronx'},
#   {'geometry': {'location': {'lat': 40.89043530000001,
#      'lng': -73.90531539999999},
#     'viewport': {'northeast': {'lat': 40.8917837302915,
#       'lng': -73.9040710197085},
#      'southwest': {'lat': 40.8890857697085, 'lng': -73.9067689802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/school-71.png',
#    'id': 'd1e3020b2ea721c2f419da2b94f1617aed3eb5a1',
#    'name': 'Yoga for Bliss',
#    'place_id': 'ChIJiyu3PrrzwokRlx8cS-wdJtk',
#    'plus_code': {'compound_code': 'V3RV+5V New York, United States',
#     'global_code': '87G8V3RV+5V'},
#    'rating': 5,
#    'reference': 'ChIJiyu3PrrzwokRlx8cS-wdJtk',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '4450 Fieldston Road, The Bronx'},
#   {'geometry': {'location': {'lat': 40.8870376, 'lng': -73.906795},
#     'viewport': {'northeast': {'lat': 40.8883577302915,
#       'lng': -73.9053184197085},
#      'southwest': {'lat': 40.8856597697085, 'lng': -73.9080163802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'ec9aa23bd7556434858ed4894742cc5a5d1956f1',
#    'name': 'OPEX Riverdale NYC',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1335,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118221022538202334234/photos">OPEX Riverdale NYC</a>'],
#      'photo_reference': 'CmRaAAAAqDQV846cnWKQhCDIytTxu-xF8rvlVtWuFcuMIZXDMS-8u_I-IXUZNMWHZ8SgeV78sYov0B04QZONXT9Qb0WxtmW_x0DN_VMOPEfYOHAwMPK40Edsx7ZAbni_rjOm6TuzEhCHjNalwJsnMTvxgMBeI0QjGhToLmlvDypMBOK2LzqTY2FXlTC9tg',
#      'width': 2000}],
#    'place_id': 'ChIJ3b1tXS7zwokRJbSHcEXWKgU',
#    'plus_code': {'compound_code': 'V3PV+R7 The Bronx, New York, United States',
#     'global_code': '87G8V3PV+R7'},
#    'rating': 5,
#    'reference': 'ChIJ3b1tXS7zwokRJbSHcEXWKgU',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': '3603 Fieldston Road, The Bronx'}],
#  'status': 'OK'}
